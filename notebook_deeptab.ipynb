# %%
# !git clone https://github.com/BBounajma/CAT-AI.git
# Out:
# fatal: destination path 'CAT-AI' already exists and is not an empty directory.

# %%
import sys
sys.path.append("/content/repo")
# !ls /content
# Out:
# CAT-AI	sample_data

# %%
# !python /content/CAT-AI/deeptab_test1.py
# Out:
# Traceback (most recent call last):
#   File "/content/CAT-AI/deeptab_test1.py", line 12, in <module>
#     from deeptab.models import SAINTClassifier
#   File "/usr/local/lib/python3.12/dist-packages/deeptab/__init__.py", line 1, in <module>
#     from . import base_models, data_utils, models, utils
#   File "/usr/local/lib/python3.12/dist-packages/deeptab/base_models/__init__.py", line 1, in <module>
#     from .ft_transformer import FTTransformer
#   File "/usr/local/lib/python3.12/dist-packages/deeptab/base_models/ft_transformer.py", line 8, in <module>
#     from .utils.basemodel import BaseModel
#   File "/usr/local/lib/python3.12/dist-packages/deeptab/base_models/utils/__init__.py", line 2, in <module>
#     from .lightning_wrapper import TaskModel
#   File "/usr/local/lib/python3.12/dist-packages/deeptab/base_models/utils/lightning_wrapper.py", line 3, in <module>
#     import lightning as pl
# ...

# %%
# !pip install -r /content/CAT-AI/requirements.txt

# %%
import pandas as pd
import numpy as np
import sys
import os
import joblib
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# DeepTab imports (deferred to avoid circular import issues)
try:
    from deeptab.models import SAINTClassifier
except AttributeError as e:
    print(f"Warning: {e}")
    print("DeepTab imports have version conflicts. Please update dependencies.")
# Out:
# ...
# DeepTab imports have version conflicts. Please update dependencies.
